# %%
import keras
import numpy as np
from keras.applications import vgg16
# Out:
# Using TensorFlow backend.

# %%
vgg_model = vgg16.VGG16(weights='imagenet')

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
filename = 'test25.jpg'

# %%
orginal = load_img(filename)
x3image=load_img(filename,target_size=(672,672))
image = load_img(filename, target_size=(224, 224))

# %%
print('PIL image size',image.size)
numpy_image = img_to_array(image)
print('numpy array size',numpy_image.shape)
# Convert the image / images into batch format
# expand_dims will add an extra dimension to the data at a particular axis
# We want the input matrix to the network to be of the form (batchsize, height, width, channels)
# Thus we add the extra dimension to the axis 0.
image_batch = np.expand_dims(numpy_image, axis=0)
print('image batch size', image_batch.shape)
plt.imshow(np.uint8(image_batch[0]))
# Out:
# PIL image size (224, 224)
# numpy array size (224, 224, 3)
# image batch size (1, 224, 224, 3)

# %%
processed_image = vgg16.preprocess_input(image_batch.copy())
predictions = vgg_model.predict(processed_image)
label = decode_predictions(predictions)
print(label)
# Out:
# [[('n04409515', 'tennis_ball', 0.9759748), ('n04039381', 'racket', 0.011194249), ('n07749582', 'lemon', 0.0071303737), ('n07742313', 'Granny_Smith', 0.0018997916), ('n12267677', 'acorn', 0.00047651224)]]

# %%
def clean(a):
    main_str=a[0][0][1]
    main_prob=a[0][0][2]
    return([main_str,main_prob])

# %%
def predict(imae):
    numpy_imae = img_to_array(imae)
    imae_batch = np.expand_dims(numpy_imae, axis=0)
    processed_imae = vgg16.preprocess_input(imae_batch.copy())
    predictions = vgg_model.predict(processed_imae)
    label = decode_predictions(predictions)
    return(label)

# %%
main_pred=clean(predict(image))[0]
main_prob=clean(predict(image))[1]

# %%
pro_image=orginal.resize(((orginal.size[0]//224)*224,(orginal.size[1]//224)*224))

# %%
pro_a=[]
upper=0
lower=pro_image.size[1]//4
while(lower<=pro_image.size[1]):
    left=0
    right=pro_image.size[0]//6
    while(right<=pro_image.size[0]):
        pro_a.append((left,upper,right,lower))
        left+=(pro_image.size[0]//6)//3
        right+=(pro_image.size[0]//6)//3
    upper+=(pro_image.size[1]//4)//2
    lower+=(pro_image.size[1]//4)//2

# %%
clean(predict(pro_image.crop(pro_a[14]).resize((224,224))))#for just checking a section of the image
# Out:
# ['screw', 0.029422995]

# %%
a=0
pro_data=[]
prob_dat=[]
for i in pro_a:
    b=clean(predict(pro_image.crop(i).resize((224,224))))
    b.append(a)
    print(b," index ",a)
    a+=1
    pro_data.append(b)
    prob_dat.append(b[1])
# Out:
# ['golf_ball', 0.03864923, 0]  index  0
# ['golf_ball', 0.05702245, 1]  index  1
# ['golf_ball', 0.16056283, 2]  index  2
# ['golf_ball', 0.12098026, 3]  index  3
# ['golf_ball', 0.07236972, 4]  index  4
# ['golf_ball', 0.06784235, 5]  index  5
# ['rapeseed', 0.03026114, 6]  index  6
# ['lycaenid', 0.06018392, 7]  index  7
# ['lycaenid', 0.07678753, 8]  index  8
# ['mantis', 0.06729306, 9]  index  9
# ['golf_ball', 0.052316487, 10]  index  10
# ['golf_ball', 0.039691117, 11]  index  11
# ['matchstick', 0.02457346, 12]  index  12
# ['matchstick', 0.026088633, 13]  index  13
# ['screw', 0.029422995, 14]  index  14
# ['golf_ball', 0.020796992, 15]  index  15
# ['tennis_ball', 0.0371068, 16]  index  16
# ['golf_ball', 0.05215709, 17]  index  17
# ['golf_ball', 0.041025635, 18]  index  18
# ['golf_ball', 0.030184498, 19]  index  19
# ['picket_fence', 0.025294289, 20]  index  20
# ['golf_ball', 0.028537346, 21]  index  21
# ['golf_ball', 0.028785456, 22]  index  22
# ['tennis_ball', 0.061937097, 23]  index  23
# ['golf_ball', 0.07760953, 24]  index  24
# ['golf_ball', 0.066299945, 25]  index  25
# ['golf_ball', 0.05852137, 26]  index  26
# ['golf_ball', 0.034878213, 27]  index  27
# ['nail', 0.019898834, 28]  index  28
# ['car_mirror', 0.019978903, 29]  index  29
# ['car_mirror', 0.015522755, 30]  index  30
# ['car_mirror', 0.029318748, 31]  index  31
# ['American_egret', 0.03181106, 32]  index  32
# ['horizontal_bar', 0.028112244, 33]  index  33
# ['horizontal_bar', 0.027938472, 34]  index  34
# ['horizontal_bar', 0.028890515, 35]  index  35
# ['horizontal_bar', 0.02759957, 36]  index  36
# ['horizontal_bar', 0.030862393, 37]  index  37
# ['tennis_ball', 0.20581654, 38]  index  38
# ['tennis_ball', 0.996259, 39]  index  39
# ['tennis_ball', 0.9993598, 40]  index  40
# ['tennis_ball', 0.9994885, 41]  index  41
# ['tennis_ball', 0.99850416, 42]  index  42
# ['tennis_ball', 0.9980817, 43]  index  43
# ['tennis_ball', 0.8290131, 44]  index  44
# ['horizontal_bar', 0.042578254, 45]  index  45
# ['horizontal_bar', 0.045106143, 46]  index  46
# ['horizontal_bar', 0.08700596, 47]  index  47
# ['ping-pong_ball', 0.050489586, 48]  index  48
# ['ping-pong_ball', 0.08655893, 49]  index  49
# ['ping-pong_ball', 0.09130354, 50]  index  50
# ['ping-pong_ball', 0.09469001, 51]  index  51
# ['ping-pong_ball', 0.072137825, 52]  index  52
# ['ping-pong_ball', 0.050902426, 53]  index  53
# ['tennis_ball', 0.98959935, 54]  index  54
# ['tennis_ball', 0.9993007, 55]  index  55
# ['tennis_ball', 0.9996152, 56]  index  56
# ['tennis_ball', 0.9999062, 57]  index  57
# ['tennis_ball', 0.9998636, 58]  index  58
# ['tennis_ball', 0.9995845, 59]  index  59
# ['tennis_ball', 0.9990717, 60]  index  60
# ['ping-pong_ball', 0.16341448, 61]  index  61
# ['pool_table', 0.160653, 62]  index  62
# ['ping-pong_ball', 0.18270709, 63]  index  63
# ['ping-pong_ball', 0.049473494, 64]  index  64
# ['ping-pong_ball', 0.07664025, 65]  index  65
# ['ping-pong_ball', 0.054472465, 66]  index  66
# ['ping-pong_ball', 0.05166452, 67]  index  67
# ['ping-pong_ball', 0.036051802, 68]  index  68
# ['tennis_ball', 0.034829058, 69]  index  69
# ['tennis_ball', 0.9891916, 70]  index  70
# ['tennis_ball', 0.9987937, 71]  index  71
# ['tennis_ball', 0.99987936, 72]  index  72
# ['tennis_ball', 0.9995969, 73]  index  73
# ['tennis_ball', 0.9999448, 74]  index  74
# ['tennis_ball', 0.98907125, 75]  index  75
# ['tennis_ball', 0.99749917, 76]  index  76
# ['ping-pong_ball', 0.049541928, 77]  index  77
# ['ping-pong_ball', 0.046237864, 78]  index  78
# ['pool_table', 0.1397463, 79]  index  79
# ['tennis_ball', 0.02773514, 80]  index  80
# ['tennis_ball', 0.047449544, 81]  index  81
# ['tennis_ball', 0.039889727, 82]  index  82
# ['tennis_ball', 0.031908393, 83]  index  83
# ['wing', 0.048302133, 84]  index  84
# ['golf_ball', 0.06529219, 85]  index  85
# ['tennis_ball', 0.47978145, 86]  index  86
# ['tennis_ball', 0.9629677, 87]  index  87
# ['tennis_ball', 0.9992138, 88]  index  88
# ['tennis_ball', 0.99489933, 89]  index  89
# ['tennis_ball', 0.9265339, 90]  index  90
# ['Granny_Smith', 0.7260163, 91]  index  91
# ['leafhopper', 0.1702512, 92]  index  92
# ['hammerhead', 0.049294945, 93]  index  93
# ['wing', 0.07075535, 94]  index  94
# ['wing', 0.035219006, 95]  index  95
# ['hammerhead', 0.1156644, 96]  index  96
# ['hammerhead', 0.09219876, 97]  index  97
# ['hammerhead', 0.08735052, 98]  index  98
# ['hammerhead', 0.021952415, 99]  index  99
# ['wing', 0.03839677, 100]  index  100
# ['wing', 0.037457254, 101]  index  101
# ['wing', 0.043349013, 102]  index  102
# ['green_lizard', 0.078910194, 103]  index  103
# ['green_lizard', 0.036459815, 104]  index  104
# ['tennis_ball', 0.030648593, 105]  index  105
# ['ladybug', 0.019948823, 106]  index  106
# ['pick', 0.02699893, 107]  index  107
# ['hammerhead', 0.06761984, 108]  index  108
# ['hammerhead', 0.07527901, 109]  index  109
# ['hammerhead', 0.0804847, 110]  index  110
# ['hammerhead', 0.06842268, 111]  index  111

# %%
z=[]
for i in range(5):
    z.append(max(prob_dat))
    prob_dat.remove(max(prob_dat))

# %%
pro_data_ref_num=[]
test_list=[]
for  i in pro_data:
    if(i[0]==main_pred and i[1]>=0.95*max(prob_dat) and i[1]>=min(z)):
        
        test_list.append(i[1])
        print(i)
        pro_data_ref_num.append(i[2])
# Out:
# ['tennis_ball', 0.9996152, 56]
# ['tennis_ball', 0.9999062, 57]
# ['tennis_ball', 0.9998636, 58]
# ['tennis_ball', 0.99987936, 72]
# ['tennis_ball', 0.9999448, 74]

# %%
fle=[]
fri=[]
flo=[]
fup=[]
for i in pro_data_ref_num:
    print(pro_a[i])
    fle.append(pro_a[i][0])
    fri.append(pro_a[i][2])
    flo.append(pro_a[i][3])
    fup.append(pro_a[i][1])
plt.imshow(pro_image.crop((min(fle),min(fup),max(fri),max(flo))))
# Out:
# (592, 336, 816, 560)
# (666, 336, 890, 560)
# (740, 336, 964, 560)
# (592, 448, 816, 672)
# (740, 448, 964, 672)

# %%
pro_image.save('1.jpg')
img=cv2.imread('1.jpg',cv2.IMREAD_COLOR)
cv2.rectangle(img,(min(fle),min(fup)),(max(fri),max(flo)),(255,0,0),10)
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,main_pred,(min(fle),min(fup)),font,4,(255,0,0),8,cv2.LINE_AA)
plt.imshow(np.uint8(img))
print(main_pred)
# Out:
# tennis_ball
