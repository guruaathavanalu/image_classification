# %%
import keras
import numpy as np
from keras.applications import vgg16
# Out:
# Using TensorFlow backend.

# %%
vgg_model = vgg16.VGG16(weights='imagenet')

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
filename = 'test26.jpg'

# %%
orginal = load_img(filename)
x3image=load_img(filename,target_size=(672,672))
image = load_img(filename, target_size=(224, 224))

# %%
print('PIL image size',image.size)
numpy_image = img_to_array(image)
print('numpy array size',numpy_image.shape)
# Convert the image / images into batch format
# expand_dims will add an extra dimension to the data at a particular axis
# We want the input matrix to the network to be of the form (batchsize, height, width, channels)
# Thus we add the extra dimension to the axis 0.
image_batch = np.expand_dims(numpy_image, axis=0)
print('image batch size', image_batch.shape)
plt.imshow(np.uint8(image_batch[0]))
# Out:
# PIL image size (224, 224)
# numpy array size (224, 224, 3)
# image batch size (1, 224, 224, 3)

# %%
processed_image = vgg16.preprocess_input(image_batch.copy())
predictions = vgg_model.predict(processed_image)
label = decode_predictions(predictions)
print(label)
# Out:
# [[('n02802426', 'basketball', 0.99945027), ('n03942813', 'ping-pong_ball', 0.00023982125), ('n07747607', 'orange', 9.614286e-05), ('n04023962', 'punching_bag', 2.2963184e-05), ('n04597913', 'wooden_spoon', 2.2235487e-05)]]

# %%
def clean(a):
    main_str=a[0][0][1]
    main_prob=a[0][0][2]
    return([main_str,main_prob])

# %%
def predict(imae):
    numpy_imae = img_to_array(imae)
    imae_batch = np.expand_dims(numpy_imae, axis=0)
    processed_imae = vgg16.preprocess_input(imae_batch.copy())
    predictions = vgg_model.predict(processed_imae)
    label = decode_predictions(predictions)
    return(label)

# %%
main_pred=clean(predict(image))[0]
main_prob=clean(predict(image))[1]

# %%
pro_image=orginal.resize(((orginal.size[0]//224)*224,(orginal.size[1]//224)*224))

# %%
pro_a=[]
upper=0
lower=pro_image.size[1]//4
while(lower<=pro_image.size[1]):
    left=0
    right=pro_image.size[0]//6
    while(right<=pro_image.size[0]):
        pro_a.append((left,upper,right,lower))
        left+=(pro_image.size[0]//6)//3
        right+=(pro_image.size[0]//6)//3
    upper+=(pro_image.size[1]//4)//2
    lower+=(pro_image.size[1]//4)//2

# %%
clean(predict(pro_image.crop(pro_a[14]).resize((224,224))))#for just checking a section of the image
# Out:
# ['flamingo', 0.1727939]

# %%
a=0
pro_data=[]
prob_dat=[]
for i in pro_a:
    b=clean(predict(pro_image.crop(i).resize((224,224))))
    b.append(a)
    print(b," index ",a)
    a+=1
    pro_data.append(b)
    prob_dat.append(b[1])
# Out:
# ['vine_snake', 0.027335582, 0]  index  0
# ['vine_snake', 0.02140653, 1]  index  1
# ['ptarmigan', 0.01780828, 2]  index  2
# ['vine_snake', 0.014566669, 3]  index  3
# ['digital_clock', 0.14610453, 4]  index  4
# ['digital_clock', 0.18384568, 5]  index  5
# ['digital_clock', 0.16421536, 6]  index  6
# ['ping-pong_ball', 0.13229871, 7]  index  7
# ['Band_Aid', 0.13101125, 8]  index  8
# ['Band_Aid', 0.3550118, 9]  index  9
# ['basketball', 0.25337622, 10]  index  10
# ['basketball', 0.703448, 11]  index  11
# ['basketball', 0.6414127, 12]  index  12
# ['basketball', 0.52898973, 13]  index  13
# ['flamingo', 0.1727939, 14]  index  14
# ['chickadee', 0.025781656, 15]  index  15
# ['ptarmigan', 0.028414618, 16]  index  16
# ['ptarmigan', 0.032009155, 17]  index  17
# ['water_ouzel', 0.028100545, 18]  index  18
# ['horizontal_bar', 0.043800868, 19]  index  19
# ['digital_clock', 0.21447963, 20]  index  20
# ['digital_clock', 0.22342464, 21]  index  21
# ['ping-pong_ball', 0.16009311, 22]  index  22
# ['ping-pong_ball', 0.28914982, 23]  index  23
# ['basketball', 0.46250308, 24]  index  24
# ['basketball', 0.7508329, 25]  index  25
# ['basketball', 0.52114755, 26]  index  26
# ['basketball', 0.8734767, 27]  index  27
# ['basketball', 0.98449564, 28]  index  28
# ['basketball', 0.99137443, 29]  index  29
# ['basketball', 0.6979032, 30]  index  30
# ['flamingo', 0.51876223, 31]  index  31
# ['balance_beam', 0.051396366, 32]  index  32
# ['balance_beam', 0.09261395, 33]  index  33
# ['balance_beam', 0.10398532, 34]  index  34
# ['horizontal_bar', 0.072177835, 35]  index  35
# ['balance_beam', 0.08244107, 36]  index  36
# ['parking_meter', 0.07837358, 37]  index  37
# ['basketball', 0.16662617, 38]  index  38
# ['basketball', 0.8477485, 39]  index  39
# ['basketball', 0.77483684, 40]  index  40
# ['basketball', 0.8589618, 41]  index  41
# ['basketball', 0.7402995, 42]  index  42
# ['basketball', 0.6925265, 43]  index  43
# ['basketball', 0.9864587, 44]  index  44
# ['basketball', 0.99542254, 45]  index  45
# ['basketball', 0.9986992, 46]  index  46
# ['basketball', 0.8641881, 47]  index  47
# ['parking_meter', 0.040031828, 48]  index  48
# ['balance_beam', 0.1057414, 49]  index  49
# ['balance_beam', 0.060760293, 50]  index  50
# ['black_grouse', 0.043553352, 51]  index  51
# ['bald_eagle', 0.04206558, 52]  index  52
# ['hip', 0.015982255, 53]  index  53
# ['basketball', 0.2315506, 54]  index  54
# ['basketball', 0.9716914, 55]  index  55
# ['basketball', 0.9889113, 56]  index  56
# ['basketball', 0.9544916, 57]  index  57
# ['basketball', 0.7027101, 58]  index  58
# ['basketball', 0.7990186, 59]  index  59
# ['basketball', 0.92659783, 60]  index  60
# ['basketball', 0.9916448, 61]  index  61
# ['basketball', 0.999795, 62]  index  62
# ['basketball', 0.994091, 63]  index  63
# ['ostrich', 0.01822823, 64]  index  64
# ['parking_meter', 0.016683666, 65]  index  65
# ['bald_eagle', 0.032238442, 66]  index  66
# ['bald_eagle', 0.029231422, 67]  index  67
# ['balance_beam', 0.024760274, 68]  index  68
# ['water_ouzel', 0.018034037, 69]  index  69
# ['flamingo', 0.1774902, 70]  index  70
# ['basketball', 0.97752315, 71]  index  71
# ['basketball', 0.9972356, 72]  index  72
# ['basketball', 0.9853457, 73]  index  73
# ['basketball', 0.9537908, 74]  index  74
# ['basketball', 0.9308535, 75]  index  75
# ['basketball', 0.990991, 76]  index  76
# ['basketball', 0.99660933, 77]  index  77
# ['basketball', 0.99858344, 78]  index  78
# ['basketball', 0.9609416, 79]  index  79
# ['water_ouzel', 0.032851238, 80]  index  80
# ['water_ouzel', 0.07732053, 81]  index  81
# ['water_ouzel', 0.062452503, 82]  index  82
# ['water_ouzel', 0.09930652, 83]  index  83
# ['water_ouzel', 0.0464831, 84]  index  84
# ['American_coot', 0.05822404, 85]  index  85
# ['puck', 0.030490901, 86]  index  86
# ['basketball', 0.20489034, 87]  index  87
# ['basketball', 0.96105886, 88]  index  88
# ['basketball', 0.9768463, 89]  index  89
# ['basketball', 0.9698289, 90]  index  90
# ['basketball', 0.97578114, 91]  index  91
# ['basketball', 0.979855, 92]  index  92
# ['basketball', 0.9711335, 93]  index  93
# ['basketball', 0.55714184, 94]  index  94
# ['basketball', 0.23756596, 95]  index  95
# ['lemon', 0.10792908, 96]  index  96
# ['lemon', 0.1381561, 97]  index  97
# ['tick', 0.052003555, 98]  index  98
# ['harvestman', 0.16410543, 99]  index  99
# ['harvestman', 0.13391371, 100]  index  100
# ['cockroach', 0.059513055, 101]  index  101
# ['puck', 0.050913237, 102]  index  102
# ['lemon', 0.054193072, 103]  index  103
# ['cockroach', 0.07431681, 104]  index  104
# ['orange', 0.22070289, 105]  index  105
# ['basketball', 0.20989656, 106]  index  106
# ['basketball', 0.17306466, 107]  index  107
# ['basketball', 0.068039134, 108]  index  108
# ['rubber_eraser', 0.06796452, 109]  index  109
# ['dough', 0.11742368, 110]  index  110
# ['lemon', 0.14875628, 111]  index  111

# %%
z=[]
for i in range(10):
    z.append(max(prob_dat))
    prob_dat.remove(max(prob_dat))

# %%
pro_data_ref_num=[]
test_list=[]
for  i in pro_data:
    if(i[0]==main_pred and i[1]>=0.65*max(prob_dat) and i[1]>=min(z)):
        
        test_list.append(i[1])
        print(i)
        pro_data_ref_num.append(i[2])
# Out:
# ['basketball', 0.99137443, 29]
# ['basketball', 0.99542254, 45]
# ['basketball', 0.9986992, 46]
# ['basketball', 0.9916448, 61]
# ['basketball', 0.999795, 62]
# ['basketball', 0.994091, 63]
# ['basketball', 0.9972356, 72]
# ['basketball', 0.990991, 76]
# ['basketball', 0.99660933, 77]
# ['basketball', 0.99858344, 78]

# %%
fle=[]
fri=[]
flo=[]
fup=[]
for i in pro_data_ref_num:
    print(pro_a[i])
    fle.append(pro_a[i][0])
    fri.append(pro_a[i][2])
    flo.append(pro_a[i][3])
    fup.append(pro_a[i][1])
plt.imshow(pro_image.crop((min(fle),min(fup),max(fri),max(flo))))
# Out:
# (806, 84, 992, 252)
# (806, 168, 992, 336)
# (868, 168, 1054, 336)
# (806, 252, 992, 420)
# (868, 252, 1054, 420)
# (930, 252, 1116, 420)
# (496, 336, 682, 504)
# (744, 336, 930, 504)
# (806, 336, 992, 504)
# (868, 336, 1054, 504)

# %%
pro_image.save('1.jpg')
img=cv2.imread('1.jpg',cv2.IMREAD_COLOR)
cv2.rectangle(img,(min(fle),min(fup)),(max(fri),max(flo)),(255,0,0),10)
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,main_pred,(min(fle),min(fup)),font,4,(255,0,0),8,cv2.LINE_AA)
plt.imshow(np.uint8(img))
print(main_pred)
# Out:
# basketball
